# %%
# %%bash
# set -e
# source /opt/conda/etc/profile.d/conda.sh
# conda activate habitatEnv
# cd /content/Habitat
# python -m habitat_sim.utils.datasets_download --uids replica_cad_dataset --data-path /content/Habitat/datasets

# %%
# %%bash
# set -e
# source /opt/conda/etc/profile.d/conda.sh
# conda activate habitatEnv
# cd /content/Habitat
# python - <<'PY'
# import runpy
# import sys
#
# sys.path.insert(0, '/content/Habitat')
# runpy.run_path('/content/Habitat/code/runners/replicacad_rgb_depth_semantic.py', run_name='__main__')
# PY
# ls -lh outputs/videos

# %%
from IPython.display import Video
Video('/content/Habitat/outputs/videos/replicacad_rgb_depth_semantic.mp4', embed=True)
