# %% [markdown]
# # Multi-Agent Example
#
# This notebook runs a simple two-agent Habitat-Sim example on the small test scene from `01_env_setup.ipynb` and records a side-by-side RGB video.

# %% [markdown]
# ## Runtime Assumptions
#
# - `01_env_setup.ipynb` has already completed in this Colab runtime.
# - The test scene exists under `/content/Habitat/datasets/test_scenes`.
# - This notebook uses Habitat-Sim directly rather than Habitat-Lab tasks.

# %%
from pathlib import Path
import os

PROJECT_ROOT = Path('/content/Habitat')
SCENE_PATH = PROJECT_ROOT / 'datasets' / 'test_scenes' / 'skokloster-castle.glb'

os.chdir(PROJECT_ROOT)
print('PROJECT_ROOT:', PROJECT_ROOT)
print('SCENE_PATH exists:', SCENE_PATH.exists())
print('SCENE_PATH:', SCENE_PATH)
# Out:
# PROJECT_ROOT: /content/Habitat
# SCENE_PATH exists: True
# SCENE_PATH: /content/Habitat/datasets/test_scenes/skokloster-castle.glb

# %%
# %%bash
# set -e
# source /opt/conda/etc/profile.d/conda.sh
# conda activate habitatEnv
# cd /content/Habitat
#
# python - <<'PY'
# import habitat_sim
# print('habitat_sim:', habitat_sim.__version__)
# print('Simulator supports multi-agent sensor queries via get_sensor_observations(agent_ids=[...]).')
# PY
# Out:
# habitat_sim: 0.3.3
# Simulator supports multi-agent sensor queries via get_sensor_observations(agent_ids=[...]).

# %%
# %%bash
# set -e
# source /opt/conda/etc/profile.d/conda.sh
# conda activate habitatEnv
# cd /content/Habitat
# test -f /content/Habitat/code/runners/multiagent_rgb_video.py || { echo 'Missing multiagent runner. Pull latest repo changes first.'; exit 1; }
# python - <<'PY'
# import runpy
# import sys
#
# sys.path.insert(0, '/content/Habitat')
# runpy.run_path('/content/Habitat/code/runners/multiagent_rgb_video.py', run_name='__main__')
# PY
# ls -lh outputs/videos
# Out:
# Traceback (most recent call last):
#   File "<stdin>", line 5, in <module>
#   File "/opt/conda/envs/habitatEnv/lib/python3.9/runpy.py", line 287, in run_path
#     code, fname = _get_code_from_file(run_name, path_name)
#   File "/opt/conda/envs/habitatEnv/lib/python3.9/runpy.py", line 252, in _get_code_from_file
#     with io.open_code(decoded_path) as f:
# FileNotFoundError: [Errno 2] No such file or directory: '/content/Habitat/code/runners/multiagent_rgb_video.py'
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# /tmp/ipykernel_450/1810293807.py in <cell line: 0>()
# ...

# %%
from IPython.display import Video
Video('/content/Habitat/outputs/videos/multiagent_rgb_agents_0_1.mp4', embed=True)
