# %%
from pathlib import Path
import os

PROJECT_ROOT = Path('/content/Habitat')
SCENE_PATH = PROJECT_ROOT / 'datasets' / 'test_scenes' / 'skokloster-castle.glb'

os.chdir(PROJECT_ROOT)
print('PROJECT_ROOT:', PROJECT_ROOT)
print('SCENE_PATH exists:', SCENE_PATH.exists())
print('SCENE_PATH:', SCENE_PATH)
# Out:
# PROJECT_ROOT: /content/Habitat
# SCENE_PATH exists: True
# SCENE_PATH: /content/Habitat/datasets/test_scenes/skokloster-castle.glb

# %%
# %%bash
# set -e
# source /opt/conda/etc/profile.d/conda.sh
# conda activate habitatEnv
# cd /content/Habitat
#
# python - <<'PY'
# import habitat_sim
# print('habitat_sim:', habitat_sim.__version__)
# print('Simulator supports multi-agent')
# PY
# Out:
# bash: line 2: /opt/conda/etc/profile.d/conda.sh: No such file or directory
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# /tmp/ipykernel_788/3482917705.py in <cell line: 0>()
# ----> 1 get_ipython().run_cell_magic('bash', '', "set -e\nsource /opt/conda/etc/profile.d/conda.sh\nconda activate habitatEnv\ncd /content/Habitat\n\npython - <<'PY'\nimport habitat_sim\nprint('habitat_sim:', habitat_sim.__version__)\nprint('Simulator supports multi-agent sensor queries via get_sensor_observations(agent_ids=[...]).')\nPY\n")
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_shell.py in run_cell_magic(self, magic_name, line, cell)
#     221     if line and not cell:
#     222       cell = ' '
# --> 223     return super().run_cell_magic(magic_name, line, cell)
#     224
#     225
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2471             with self.builtin_trap:
#    2472                 args = (magic_arg_s, cell)
# -> 2473                 result = fn(*args, **kwargs)
#    2474             return result
#    2475
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/magics/script.py in named_script_magic(line, cell)
#     140             else:
#     141                 line = script
# --> 142             return self.shebang(line, cell)
#     143
#     144         # write a basic docstring:
#
# <decorator-gen-103> in shebang(self, line, cell)
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/magics/script.py in shebang(self, line, cell)
#     243             sys.stderr.flush()
#     244         if args.raise_error and p.returncode!=0:
# --> 245             raise CalledProcessError(p.returncode, cell, output=out, stderr=err)
#     246
#     247     def _run_script(self, p, cell, to_close):
#
# CalledProcessError: Command 'b"set -e\nsource /opt/conda/etc/profile.d/conda.sh\nconda activate habitatEnv\ncd /content/Habitat\n\npython - <<'PY'\nimport habitat_sim\nprint('habitat_sim:', habitat_sim.__version__)\nprint('Simulator supports multi-agent sensor queries via get_sensor_observations(agent_ids=[...]).')\nPY\n"' returned non-zero exit status 1.

# %%
# %%bash
# set -e
# source /opt/conda/etc/profile.d/conda.sh
# conda activate habitatEnv
# cd /content/Habitat
# test -f /content/Habitat/code/runners/multiagent_rgb_video.py || { echo 'Missing multiagent runner. Pull latest repo changes first.'; exit 1; }
# python - <<'PY'
# import runpy
# import sys
#
# sys.path.insert(0, '/content/Habitat')
# runpy.run_path('/content/Habitat/code/runners/multiagent_rgb_video.py', run_name='__main__')
# PY
# ls -lh outputs/videos
# Out:
# Renderer: Tesla T4/PCIe/SSE2 by NVIDIA Corporation
# OpenGL version: 4.6.0 NVIDIA 580.82.07
# Using optional features:
#     GL_ARB_vertex_array_object
#     GL_ARB_separate_shader_objects
#     GL_ARB_robustness
#     GL_ARB_texture_storage
#     GL_ARB_texture_view
#     GL_ARB_framebuffer_no_attachments
#     GL_ARB_invalidate_subdata
#     GL_ARB_texture_storage_multisample
#     GL_ARB_multi_bind
#     GL_ARB_direct_state_access
#     GL_ARB_get_texture_sub_image
#     GL_ARB_texture_filter_anisotropic
#     GL_KHR_debug
#     GL_KHR_parallel_shader_compile
#     GL_NV_depth_buffer_float
# Using driver workarounds:
#     no-forward-compatible-core-context
#     nv-egl-incorrect-gl11-function-pointers
#     no-layout-qualifiers-on-old-glsl
#     nv-zero-context-profile-mask
#     nv-implementation-color-read-format-dsa-broken
#     nv-cubemap-inconsistent-compressed-image-size
#     nv-cubemap-broken-full-compressed-image-query
#     nv-compressed-block-size-in-bits
# Saved: /content/Habitat/outputs/videos/multiagent_rgb_agents_0_1.mp4
# Agent 0 final position: [-2.7655547  0.0099186  5.982865 ]
# Agent 1 final position: [-0.72678167  0.06131994 20.902779  ]
# total 1.7M
# -rw-r--r-- 1 root root 794K Mar 10 00:26 multiagent_rgb_agents_0_1.mp4
# -rw-r--r-- 1 root root 152K Mar 10 00:13 pointnav_gibson_val_mini_rgb_depth.mp4
# -rw-r--r-- 1 root root 733K Mar 10 00:13 pointnav_gibson_val_mini_rgb_depth_semantic.mp4
# [00:26:22:164019]:[Warning]:[Metadata] SceneDatasetAttributes.cpp(107)::addNewSceneInstanceToDataset : Dataset : 'default' : Lighting Layout Attributes 'no_lights' specified in Scene Attributes but does not exist in dataset, so creating default.
# [00:26:22:165955]:[Warning]:[Scene] SemanticScene.h(331)::checkFileExists : ::loadSemanticSceneDescriptor: File `/content/Habitat/datasets/test_scenes/skokloster-castle.scn` does not exist.  Aborting load.
# [00:26:22:166005]:[Warning]:[Scene] SemanticScene.cpp(123)::loadSemanticSceneDescriptor : SSD File Naming Issue! Neither SemanticAttributes-provided name : `/content/Habitat/datasets/test_scenes/skokloster-castle.scn` nor constructed filename : `/content/Habitat/datasets/test_scenes/info_semantic.json` exist on disk.
# [00:26:22:166019]:[Error]:[Scene] SemanticScene.cpp(139)::loadSemanticSceneDescriptor : SSD Load Failure! File with SemanticAttributes-provided name `/content/Habitat/datasets/test_scenes/skokloster-castle.scn` exists but failed to load.
# [00:26:24:113217]:[Warning]:[Sim] Simulator.cpp(595)::instanceStageForSceneAttributes : The active scene does not contain semantic annotations : activeSemanticSceneID_ = 0

# %%
from IPython.display import Video
Video('/content/Habitat/outputs/videos/multiagent_rgb_agents_0_1.mp4', embed=True)
# Out:
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
