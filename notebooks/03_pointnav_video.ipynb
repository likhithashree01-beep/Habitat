# %% [markdown]
# # PointNav RGB + Depth Video
#
# This notebook records a PointNav episode video using the Gibson dataset and saves it under `outputs/videos`.

# %% [markdown]
# ## Runtime Assumptions
#
# - `01_env_setup.ipynb` has already completed in this Colab runtime.
# - `02_pointnav_example.ipynb` has already downloaded the Gibson PointNav datasets.

# %%
from pathlib import Path
import os

PROJECT_ROOT = Path('/content/Habitat')

os.chdir(PROJECT_ROOT)
print(PROJECT_ROOT)
# Out:
# /content/Habitat

# %%
# %%bash
# set -e
# source /opt/conda/etc/profile.d/conda.sh
# conda activate habitatEnv
# python -m pip -q install rich imageio imageio-ffmpeg

# %%
# %%bash
# set -e
# source /opt/conda/etc/profile.d/conda.sh
# conda activate habitatEnv
# cd /content/Habitat
# python - <<'PY'
# import runpy
# import sys
#
# sys.path.insert(0, '/content/Habitat')
# runpy.run_path('/content/Habitat/code/runners/pointnav_rgb_depth_video.py', run_name='__main__')
# PY
# ls -lh outputs/videos
# Out:
# ╭──────────────────────────────────────────────────────────────────────────────╮
# │ PointNav Gibson (val_mini)                                                   │
# │ Saving RGB|Depth video ->                                                    │
# │ /content/Habitat/outputs/videos/pointnav_gibson_val_mini_rgb_depth.mp4       │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# Renderer: Tesla T4/PCIe/SSE2 by NVIDIA Corporation
# OpenGL version: 4.6.0 NVIDIA 580.82.07
# Using optional features:
#     GL_ARB_vertex_array_object
#     GL_ARB_separate_shader_objects
#     GL_ARB_robustness
#     GL_ARB_texture_storage
#     GL_ARB_texture_view
#     GL_ARB_framebuffer_no_attachments
#     GL_ARB_invalidate_subdata
#     GL_ARB_texture_storage_multisample
#     GL_ARB_multi_bind
#     GL_ARB_direct_state_access
#     GL_ARB_get_texture_sub_image
#     GL_ARB_texture_filter_anisotropic
#     GL_KHR_debug
#     GL_KHR_parallel_shader_compile
#     GL_NV_depth_buffer_float
# Using driver workarounds:
#     no-forward-compatible-core-context
#     nv-egl-incorrect-gl11-function-pointers
#     no-layout-qualifiers-on-old-glsl
#     nv-zero-context-profile-mask
#     nv-implementation-color-read-format-dsa-broken
#     nv-cubemap-inconsistent-compressed-image-size
#     nv-cubemap-broken-full-compressed-image-query
#     nv-compressed-block-size-in-bits
# Obs keys: rgb=rgb, depth=depth
# Recording episode... ━━━━╸                                     12% 0:00:02
# Saved: /content/Habitat/outputs/videos/pointnav_gibson_val_mini_rgb_depth.mp4
# total 152K
# -rw-r--r-- 1 root root 152K Mar 10 00:13 pointnav_gibson_val_mini_rgb_depth.mp4
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# PluginManager::Manager: duplicate static plugin StbImageImporter, ignoring
# PluginManager::Manager: duplicate static plugin GltfImporter, ignoring
# PluginManager::Manager: duplicate static plugin BasisImporter, ignoring
# PluginManager::Manager: duplicate static plugin AssimpImporter, ignoring
# PluginManager::Manager: duplicate static plugin AnySceneImporter, ignoring
# PluginManager::Manager: duplicate static plugin AnyImageImporter, ignoring
# 2026-03-10 00:13:11,182 Initializing dataset PointNav-v1
# 2026-03-10 00:13:11,188 initializing sim Sim-v0
# PluginManager::Manager: duplicate static plugin StbImageImporter, ignoring
# PluginManager::Manager: duplicate static plugin GltfImporter, ignoring
# PluginManager::Manager: duplicate static plugin BasisImporter, ignoring
# PluginManager::Manager: duplicate static plugin AssimpImporter, ignoring
# PluginManager::Manager: duplicate static plugin AnySceneImporter, ignoring
# PluginManager::Manager: duplicate static plugin AnyImageImporter, ignoring
# [00:13:11:423655]:[Warning]:[Metadata] SceneDatasetAttributes.cpp(107)::addNewSceneInstanceToDataset : Dataset : 'default' : Lighting Layout Attributes 'no_lights' specified in Scene Attributes but does not exist in dataset, so creating default.
# [00:13:11:423861]:[Warning]:[Scene] SemanticScene.h(331)::checkFileExists : ::loadSemanticSceneDescriptor: File `/content/Habitat/datasets/scene_datasets/gibson/Pablo.scn` does not exist.  Aborting load.
# [00:13:11:423890]:[Warning]:[Scene] SemanticScene.cpp(123)::loadSemanticSceneDescriptor : SSD File Naming Issue! Neither SemanticAttributes-provided name : `/content/Habitat/datasets/scene_datasets/gibson/Pablo.scn` nor constructed filename : `/content/Habitat/datasets/scene_datasets/gibson/info_semantic.json` exist on disk.
# [00:13:11:423906]:[Error]:[Scene] SemanticScene.cpp(139)::loadSemanticSceneDescriptor : SSD Load Failure! File with SemanticAttributes-provided name `/content/Habitat/datasets/scene_datasets/gibson/Pablo.scn` exists but failed to load.
# [00:13:12:553111]:[Warning]:[Sim] Simulator.cpp(595)::instanceStageForSceneAttributes : The active scene does not contain semantic annotations : activeSemanticSceneID_ = 0
# 2026-03-10 00:13:12,555 Initializing task Nav-v0

# %%
from pathlib import Path
from IPython.display import Video

videos = sorted(Path('/content/Habitat/outputs/videos').glob('pointnav_gibson_*_rgb_depth.mp4'))
assert videos, 'No PointNav video found'
Video(str(videos[-1]), embed=True)
# Out:
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
